// %% [markdown]
// # DemoWeave notebook fixture
// A tiny deterministic notebook used to prove explicit notebook execution and native artifact capture.

// %%
const scores = [0.72, 0.81, 0.88, 0.93];
console.log(`best=${Math.max(...scores).toFixed(2)}`);
